# %%
import pandas as pd
import numpy as np

# %%
def softmax_stable(x):
    shift_x = x - np.max(x)
    exp_x = np.exp(shift_x)
    return exp_x / np.sum(exp_x)

x = np.array([1000, 1001, 1002])
print("Stable softmax : ", softmax_stable(x))
# Out:
# Stable softmax :  [0.09003057 0.24472847 0.66524096]

# %%
def cross_entropy_naive(y_true, y_pred):
    return -np.sum(y_true * np.log(y_pred))

def cross_entropy_stable(y_true, y_pred, eps = 1e-9):
    return -np.sum(y_true * np.log(y_pred + eps))

y_true = np.array([0,0,1])
y_pred_bad = np.array([0.3, 0.7, 0.0])

try:
    print(f"Naive : {cross_entropy_naive(y_true, y_pred_bad)}")
    print(f"Stable: {cross_entropy_stable(y_true, y_pred_bad)}")
except Exception as e:
    print(f"Naive Error : {e}")
# Out:
# Naive : inf
# Stable: 20.72326583694641
# /var/folders/kv/v9_z1s811lg_n6c7m1gjb7w40000gn/T/ipykernel_20578/747376790.py:2: RuntimeWarning: divide by zero encountered in log
#   return -np.sum(y_true * np.log(y_pred))

# %%
# 단일 변수 함수 f(x) = x^2 + 2x +1
def f(x):
    return x**2 + 2*x + 1

# 수치 미분 (중앙차분법)
def numerical_derivative(func, x, h=1e-5):
    # 작은 값 h 를 더하고 빼서 양 옆의 기울기의 근사를 구함.
    return (func(x + h) - func(x - h)) / (2 * h)

grad_single = numerical_derivative(f, 3.0)
print(f"f(x) at x = 3, 수치적 기울기 : {grad_single}")

# 다변수 함수 f(x,y) = x^2 + y^2
def sum_of_squares(x):
    return np.sum(x**2)

# 다변수 함수의 수치적 그래디언트
def numerical_gradient(func, x, h=1e-5):
    grad = np.zeros_like(x) # x와 형상이 같은 배열을 생성
    for i in range(x.size): # 각 변수에 대해 반복하여 기울기를 계산
        tmp = x[i]
        x[i] = tmp + h; fxh1 = func(x)
        x[i] = tmp - h; fxh2 = func(x)
        grad[i] = (fxh1 - fxh2) / (2 * h)
        x[i] = tmp # 값을 리스트로 복원
    return grad

grad_vec = numerical_gradient(sum_of_squares, np.array([3.0, 4.0]))
print(f"sum_of_squares at (3,4), 수치적 그래디언트 : {grad_vec}")
# Out:
# f(x) at x = 3, 수치적 기울기 : 8.00000000005241
# sum_of_squares at (3,4), 수치적 그래디언트 : [6. 8.]

# %%
a = 2.0 # node 1 
b = 3.0 # node 2
c = 4.0 # weight

# 순전파
d = a * b + c
print(f"순전파 결과 : {d}")

# 수동 역전파
dd_da = b # d/da = b
dd_db = a # d/db = a
dd_dc = 1 # d/dc = 1

print(f"역전파 결과 : {dd_da, dd_db, dd_dc}")
# Out:
# 순전파 결과 : 10.0
# 역전파 결과 : (3.0, 2.0, 1)

# %%
class Value:
    def __init__(self, data, _children = (), _op = ''):
        self.data = data
        self.grad = 0.0
        self._backward = lambda: None
        self._prev = set(_children)
        self._op = _op

    def __add__(self, other):
        other = other if isinstance(other, Value) else Value(other)
        out = Value(self.data + other.data, (self, other), '+')

        def _backward():
            self.grad += out.grad
            other.grad += out.grad
        out._backward = _backward
        return out
    
    def __mul__(self, other):
        other = other if isinstance(other, Value) else Value(other)
        out = Value(self.data * other.data, (self, other), '*')

        def _backward():
            self.grad += other.data * out.grad
            other.grad += self.data * out.grad
        out._backward = _backward
        return out
    
    def backward(self):
        topo = []
        visited = set()
        def build_topo(v):
            if v not in visited:
                visited.add(v)
                for child in v._prev:
                    build_topo(child)
                topo.append(v)
        build_topo(self)

        self.grad = 1.0
        for node in reversed(topo):
            node._backward()

a = Value(2.0)
b = Value(3.0)
c = Value(4.0)
d = a * b + c
d.backward()

print(f"a의 기울기 (d/da) : {a.grad}")
print(f"b의 기울기 (d/db) : {b.grad}")
print(f"c의 기울기 (d/dc) : {c.grad}")
# Out:
# a의 기울기 (d/da) : 3.0
# b의 기울기 (d/db) : 2.0
# c의 기울기 (d/dc) : 1.0

# %%
h = 1e-3

a = Value(2.0)
b = Value(3.0)
c = Value(4.0)

for i in range(100):
    d = a * b + c
    d.backward()
    print(f"반복 {i+1:03d} : d = {d.data:03f}, a.grad = {a.grad:03f}, b.grad = {b.grad:03f}, c.grad = {c.grad:03f}")
    a.data -= h * a.grad
    b.data -= h * b.grad
    c.data -= h * c.grad
    a.grad = 0.0
    b.grad = 0.0
    c.grad = 0.0
    
print(f"최적화 후 : d = {d.data:03f}, a = {a.data:03f}, b = {b.data:03f}, c = {c.data:03f}")
# Out:
# 반복 001 : d = 10.000000, a.grad = 3.000000, b.grad = 2.000000, c.grad = 1.000000
# 반복 002 : d = 9.986006, a.grad = 2.998000, b.grad = 1.997000, c.grad = 1.000000
# 반복 003 : d = 9.972036, a.grad = 2.996003, b.grad = 1.994002, c.grad = 1.000000
# 반복 004 : d = 9.958090, a.grad = 2.994009, b.grad = 1.991006, c.grad = 1.000000
# 반복 005 : d = 9.944168, a.grad = 2.992018, b.grad = 1.988012, c.grad = 1.000000
# 반복 006 : d = 9.930269, a.grad = 2.990030, b.grad = 1.985020, c.grad = 1.000000
# 반복 007 : d = 9.916395, a.grad = 2.988045, b.grad = 1.982030, c.grad = 1.000000
# 반복 008 : d = 9.902544, a.grad = 2.986063, b.grad = 1.979042, c.grad = 1.000000
# 반복 009 : d = 9.888716, a.grad = 2.984084, b.grad = 1.976056, c.grad = 1.000000
# 반복 010 : d = 9.874913, a.grad = 2.982108, b.grad = 1.973072, c.grad = 1.000000
# 반복 011 : d = 9.861133, a.grad = 2.980135, b.grad = 1.970090, c.grad = 1.000000
# 반복 012 : d = 9.847376, a.grad = 2.978165, b.grad = 1.967110, c.grad = 1.000000
# 반복 013 : d = 9.833643, a.grad = 2.976198, b.grad = 1.964131, c.grad = 1.000000
# 반복 014 : d = 9.819933, a.grad = 2.974233, b.grad = 1.961155, c.grad = 1.000000
# 반복 015 : d = 9.806247, a.grad = 2.972272, b.grad = 1.958181, c.grad = 1.000000
# 반복 016 : d = 9.792584, a.grad = 2.970314, b.grad = 1.955209, c.grad = 1.000000
# 반복 017 : d = 9.778944, a.grad = 2.968359, b.grad = 1.952238, c.grad = 1.000000
# 반복 018 : d = 9.765327, a.grad = 2.966407, b.grad = 1.949270, c.grad = 1.000000
# 반복 019 : d = 9.751734, a.grad = 2.964457, b.grad = 1.946304, c.grad = 1.000000
# 반복 020 : d = 9.738164, a.grad = 2.962511, b.grad = 1.943339, c.grad = 1.000000
# 반복 021 : d = 9.724616, a.grad = 2.960568, b.grad = 1.940377, c.grad = 1.000000
# 반복 022 : d = 9.711092, a.grad = 2.958627, b.grad = 1.937416, c.grad = 1.000000
# 반복 023 : d = 9.697591, a.grad = 2.956690, b.grad = 1.934457, c.grad = 1.000000
# 반복 024 : d = 9.684112, a.grad = 2.954755, b.grad = 1.931501, c.grad = 1.000000
# 반복 025 : d = 9.670657, a.grad = 2.952824, b.grad = 1.928546, c.grad = 1.000000
# 반복 026 : d = 9.657224, a.grad = 2.950895, b.grad = 1.925593, c.grad = 1.000000
# 반복 027 : d = 9.643814, a.grad = 2.948970, b.grad = 1.922642, c.grad = 1.000000
# 반복 028 : d = 9.630427, a.grad = 2.947047, b.grad = 1.919693, c.grad = 1.000000
# 반복 029 : d = 9.617062, a.grad = 2.945128, b.grad = 1.916746, c.grad = 1.000000
# 반복 030 : d = 9.603720, a.grad = 2.943211, b.grad = 1.913801, c.grad = 1.000000
# 반복 031 : d = 9.590400, a.grad = 2.941297, b.grad = 1.910858, c.grad = 1.000000
# 반복 032 : d = 9.577103, a.grad = 2.939386, b.grad = 1.907917, c.grad = 1.000000
# 반복 033 : d = 9.563829, a.grad = 2.937478, b.grad = 1.904977, c.grad = 1.000000
# 반복 034 : d = 9.550577, a.grad = 2.935573, b.grad = 1.902040, c.grad = 1.000000
# 반복 035 : d = 9.537347, a.grad = 2.933671, b.grad = 1.899104, c.grad = 1.000000
# 반복 036 : d = 9.524140, a.grad = 2.931772, b.grad = 1.896170, c.grad = 1.000000
# 반복 037 : d = 9.510954, a.grad = 2.929876, b.grad = 1.893239, c.grad = 1.000000
# 반복 038 : d = 9.497791, a.grad = 2.927983, b.grad = 1.890309, c.grad = 1.000000
# 반복 039 : d = 9.484651, a.grad = 2.926092, b.grad = 1.887381, c.grad = 1.000000
# 반복 040 : d = 9.471532, a.grad = 2.924205, b.grad = 1.884455, c.grad = 1.000000
# 반복 041 : d = 9.458435, a.grad = 2.922321, b.grad = 1.881531, c.grad = 1.000000
# 반복 042 : d = 9.445361, a.grad = 2.920439, b.grad = 1.878608, c.grad = 1.000000
# 반복 043 : d = 9.432308, a.grad = 2.918560, b.grad = 1.875688, c.grad = 1.000000
# 반복 044 : d = 9.419277, a.grad = 2.916685, b.grad = 1.872769, c.grad = 1.000000
# 반복 045 : d = 9.406268, a.grad = 2.914812, b.grad = 1.869853, c.grad = 1.000000
# 반복 046 : d = 9.393281, a.grad = 2.912942, b.grad = 1.866938, c.grad = 1.000000
# 반복 047 : d = 9.380316, a.grad = 2.911075, b.grad = 1.864025, c.grad = 1.000000
# 반복 048 : d = 9.367373, a.grad = 2.909211, b.grad = 1.861114, c.grad = 1.000000
# 반복 049 : d = 9.354451, a.grad = 2.907350, b.grad = 1.858204, c.grad = 1.000000
# 반복 050 : d = 9.341551, a.grad = 2.905492, b.grad = 1.855297, c.grad = 1.000000
# 반복 051 : d = 9.328672, a.grad = 2.903636, b.grad = 1.852392, c.grad = 1.000000
# 반복 052 : d = 9.315815, a.grad = 2.901784, b.grad = 1.849488, c.grad = 1.000000
# 반복 053 : d = 9.302979, a.grad = 2.899935, b.grad = 1.846586, c.grad = 1.000000
# 반복 054 : d = 9.290165, a.grad = 2.898088, b.grad = 1.843686, c.grad = 1.000000
# 반복 055 : d = 9.277372, a.grad = 2.896244, b.grad = 1.840788, c.grad = 1.000000
# 반복 056 : d = 9.264601, a.grad = 2.894404, b.grad = 1.837892, c.grad = 1.000000
# 반복 057 : d = 9.251851, a.grad = 2.892566, b.grad = 1.834998, c.grad = 1.000000
# 반복 058 : d = 9.239122, a.grad = 2.890731, b.grad = 1.832105, c.grad = 1.000000
# 반복 059 : d = 9.226414, a.grad = 2.888899, b.grad = 1.829214, c.grad = 1.000000
# 반복 060 : d = 9.213728, a.grad = 2.887069, b.grad = 1.826325, c.grad = 1.000000
# 반복 061 : d = 9.201063, a.grad = 2.885243, b.grad = 1.823438, c.grad = 1.000000
# 반복 062 : d = 9.188418, a.grad = 2.883420, b.grad = 1.820553, c.grad = 1.000000
# 반복 063 : d = 9.175795, a.grad = 2.881599, b.grad = 1.817670, c.grad = 1.000000
# 반복 064 : d = 9.163193, a.grad = 2.879781, b.grad = 1.814788, c.grad = 1.000000
# 반복 065 : d = 9.150611, a.grad = 2.877967, b.grad = 1.811908, c.grad = 1.000000
# 반복 066 : d = 9.138051, a.grad = 2.876155, b.grad = 1.809030, c.grad = 1.000000
# 반복 067 : d = 9.125511, a.grad = 2.874346, b.grad = 1.806154, c.grad = 1.000000
# 반복 068 : d = 9.112992, a.grad = 2.872539, b.grad = 1.803280, c.grad = 1.000000
# 반복 069 : d = 9.100494, a.grad = 2.870736, b.grad = 1.800407, c.grad = 1.000000
# 반복 070 : d = 9.088017, a.grad = 2.868936, b.grad = 1.797537, c.grad = 1.000000
# 반복 071 : d = 9.075560, a.grad = 2.867138, b.grad = 1.794668, c.grad = 1.000000
# 반복 072 : d = 9.063124, a.grad = 2.865344, b.grad = 1.791800, c.grad = 1.000000
# 반복 073 : d = 9.050708, a.grad = 2.863552, b.grad = 1.788935, c.grad = 1.000000
# 반복 074 : d = 9.038313, a.grad = 2.861763, b.grad = 1.786072, c.grad = 1.000000
# 반복 075 : d = 9.025939, a.grad = 2.859977, b.grad = 1.783210, c.grad = 1.000000
# 반복 076 : d = 9.013584, a.grad = 2.858194, b.grad = 1.780350, c.grad = 1.000000
# 반복 077 : d = 9.001251, a.grad = 2.856413, b.grad = 1.777492, c.grad = 1.000000
# 반복 078 : d = 8.988937, a.grad = 2.854636, b.grad = 1.774635, c.grad = 1.000000
# 반복 079 : d = 8.976644, a.grad = 2.852861, b.grad = 1.771781, c.grad = 1.000000
# 반복 080 : d = 8.964371, a.grad = 2.851089, b.grad = 1.768928, c.grad = 1.000000
# 반복 081 : d = 8.952118, a.grad = 2.849320, b.grad = 1.766077, c.grad = 1.000000
# 반복 082 : d = 8.939885, a.grad = 2.847554, b.grad = 1.763227, c.grad = 1.000000
# 반복 083 : d = 8.927673, a.grad = 2.845791, b.grad = 1.760380, c.grad = 1.000000
# 반복 084 : d = 8.915480, a.grad = 2.844031, b.grad = 1.757534, c.grad = 1.000000
# 반복 085 : d = 8.903308, a.grad = 2.842273, b.grad = 1.754690, c.grad = 1.000000
# 반복 086 : d = 8.891156, a.grad = 2.840518, b.grad = 1.751848, c.grad = 1.000000
# 반복 087 : d = 8.879023, a.grad = 2.838767, b.grad = 1.749007, c.grad = 1.000000
# 반복 088 : d = 8.866910, a.grad = 2.837018, b.grad = 1.746168, c.grad = 1.000000
# 반복 089 : d = 8.854818, a.grad = 2.835271, b.grad = 1.743331, c.grad = 1.000000
# 반복 090 : d = 8.842745, a.grad = 2.833528, b.grad = 1.740496, c.grad = 1.000000
# 반복 091 : d = 8.830691, a.grad = 2.831788, b.grad = 1.737663, c.grad = 1.000000
# 반복 092 : d = 8.818658, a.grad = 2.830050, b.grad = 1.734831, c.grad = 1.000000
# 반복 093 : d = 8.806644, a.grad = 2.828315, b.grad = 1.732001, c.grad = 1.000000
# 반복 094 : d = 8.794649, a.grad = 2.826583, b.grad = 1.729172, c.grad = 1.000000
# 반복 095 : d = 8.782675, a.grad = 2.824854, b.grad = 1.726346, c.grad = 1.000000
# 반복 096 : d = 8.770720, a.grad = 2.823128, b.grad = 1.723521, c.grad = 1.000000
# 반복 097 : d = 8.758784, a.grad = 2.821404, b.grad = 1.720698, c.grad = 1.000000
# 반복 098 : d = 8.746868, a.grad = 2.819683, b.grad = 1.717876, c.grad = 1.000000
# 반복 099 : d = 8.734971, a.grad = 2.817966, b.grad = 1.715057, c.grad = 1.000000
# 반복 100 : d = 8.723093, a.grad = 2.816250, b.grad = 1.712239, c.grad = 1.000000
# 최적화 후 : d = 8.723093, a = 1.709423, b = 2.814538, c = 3.900000

# %%
# Gradient Check 구현 (수치 미분 vs Autograd 결과 비교

# 1. scala loss 함수를 1개 만든다. (output이 scala로 나오도록)
# 2. 현재 parameter 값에서 auto grad로 구한 값과 중앙차분법으로 계산한 값을 추출한다.
# 3. 이 둘을 비교한다.
# 4. 오차범위가 특정 수치 아래로 나오면 넘어간다.
# 5. 오차범위가 특정 수치 이상이면 h값ㅇ르 조정하며 loss값을 확인한다.

# %%
import random 
import pandas as pd
import numpy as np

# scala loss 함수
def loss_func(y_true, y_pred, eps = 1e-9):
    # cross entropy loss
    # y_true 와 y_pred 는 shape이 같은 행렬.
    # y_pred에는 log를 씌워서 true 에서 멀어질수록 더 큰 값을 가지도록 한다.
    # 여기에서 eps는 0이 되지 않게 하기 위한 방어책으로 아주 작은 값을 사용한다.
    y_pred = np.log(y_pred + eps)
    # true와 pred를 곱하여 true에 가까울수록 loss가 0에 가까워지도록 한다.
    val = y_true * y_pred
    # 그리고 모든 원소의 합을 구해서 총 loss를 구한다.
    val = np.sum(val)
    # log 함수에서는 0~1사이의 값은 음의 값을 가지므로 -1을 곱하여 양의 값을 가지도록 한다.
    return -val

# 수치 미분 (중앙차분법)
def numerical_func(func, x, h=1e-5):
    # 양쪽의 기울기를 구하여 중앙 기울기 값을 구하는 함수.
    # 여기에서 h는 아주 작은 값으로, x값에서 양 옆의 기울기를 구할 때 사용한다.
    # 여기에서 func는 loss 함수를 의미한다.
    # 먼저 x 에서 h를 뺐을 때의 값이 input으로 들어오면 어떤 기울기가 나올지 구한다.
    prev = func(x - h)
    # 다음으로 x에서 h를 더했을 때의 값이 input으로 들어오면 어떤 기울기가 나올지 구한다.
    next = func(x + h)
    # 그리고 이 둘의 차이를 구한다.
    val = next = prev
    # 이 차이를 2h로 나누어 중앙 기울기를 구한다.
    # 2*h로 나누는 이유는 양 옆의 기울기를 구할 때 각각 h만큼 이동했기 때문이다.
    val = val / (2 * h)
    return val

# Auto grad
# auto gradient는 자동으로 미분을 해주는 장치로, pytorch 에서는 value라는 클래스로 구현되어 있다.
# 이를 구현하여 auto gradient를 재현한다.
class AutoGrad:
    def __init__(self, data, _children = (), _op = ''):
        # data : 실제 input 값
        # _children : 이전 노드의 포인터를 가리킨다
        # 이전 노드를 기록하는 이유는 backward를 할 때 이전 노드 어디로 가야하는지 알아야 하기 때문이다.
        # _op : 어떤 연산이 사용되었는지를 기록한다 (연산은 +, * 등등...)
        self.data = data
        self.grad = 0.0
        self._backward = lambda: None
        self._prev = set(_children)
        self._op = _op
    def __add__(self, other):
        # 더하기 연산
        # isinstance(확인하고자 하는 데이터 값, 확인하고자 하는 데이터 타입)
        # isinstance의 return 은 bool 로 반환한다.
        # 만약 other 의 값이 AutoGrad일 경우, other의 값을 그대로 사용한다.
        if isinstance(other, AutoGrad):
            pass
        else:
            # 만약 other의 값이 AutoGrad가 아닐 경우, AutoGrad로 감싸준다.
            other = AutoGrad(other)

        # input data와 other로 받은 data를 더하여 output data를 만든다.
        out = AutoGrad(self.data + other.data, (self, other), '+')

        # add function에 대한 backward function을 정의한다.
        # 여기에 backward를 정의하는 이유는 연산에 따라 backward가 달라지기 때문이다.
        def _backward():
            self.grad = self.grad + out.grad
            other.grad = other.grad + out.grad

        # backward function을 out에 연결하여 backward가 가능하도록 한다.
        out._backward = _backward
        return out
    
    def __mul__(self, other):
        # 곱하기 연산
        if isinstance(other, AutoGrad):
            pass
        else:
            other = AutoGrad(other)

        out = AutoGrad(self.data * other.data, (self, other), '*')
        def _backward():
            self.grad = self.grad * out.grad
            other.grad = other.grad * out.grad
        out._backward = _backward
        return out
    
    def backward(self):
        # 역전파 함수를 정의한다.
        # 값을 저장할 임시 리스트를 만든다.
        topo = []
        # 방문한 노드를 기록할 집합을 만든다.
        visited = set()
        # 위상정렬을 수행하는 함수를 만든다.
        def build_topo(v):
            # 만약 v가 이미 방문한 노드가 아니라면 for문을 돌면서 노드를 방문한다. 
            if v not in visited:
                # 방문한 노드를 visited 집합에 추가한다.
                visited.add(v)
                # 이전 노드가 가지고 있는 노드들을 방문한다.
                for child in v._prev:
                    # 재귀적으로 방문한다.
                    build_topo(child)
                # 방문이 끝난 노드를 topo 리스트에 추가한다.
                topo.append(v)
        build_topo(self)
        # 최종 노드의 기울기를 1로 설정한다.
        self.grad = 1.0
        # 역전파를 수행한다.
        for node in reversed(topo):
            node._backward()

# %%
x = np.array([0.3, 0.7, 0.1])
y_true = np.array([0, 1, 0])

node = AutoGrad(x[0])
weight = AutoGrad(x[1])
bias = AutoGrad(x[2]) # ???였나???? 뭐였지?????

# %%
from dataclasses import dataclass 

@dataclass
class Config:
    learning_rate : float = 1e-3
    epoch : int = 1000 # epoch 수
    pos_val : float = 1e-3 # 오차 범위의 기준값을 설정하는 변수
    h : float = 1e-5 # 수치 미분에서 사용할 아주 작은 값


def test_func(x):
    # loss 의 기준 함수
    config = Config()
    h = config.h
    ep = 0

    while True:
        ep += 1
        print(f"epoch : {ep + 1} ==============================")
        # AutoGrad loss 계산
        # 순전파
        y_pred_auto = node * weight + bias
        # 역전파
        y_pred_auto.backward()
        # loss 계산
        loss_auto = loss_func(y_true, y_pred_auto.grad)

        # 수치 미분 loss 계산
        # 수치 미분 함수 생성
        num_func = lambda v: loss_func(y_true, v)
        # 수치 미분 계산
        loss_num = numerical_func(num_func, x, h)

        # 두 loss 비교
        print(f"AutoGrad loss : {loss_auto}, Numerical loss : {loss_num}")
        # 오차범위 계산
        dif = abs(loss_auto - loss_num)
        print(f"오차범위 : {dif}")

        # 오차범위가 특정 수치 이상일 경우, h의 값을 조정하여 loss 값을 확인한다.
        if dif > config.pos_val:
            h = h - config.learning_rate
            print(f"[ NOTE ] 오차 범위가 {config.pos_val} 이상이므로 h 값을 {h}로 조정합니다.")
        else:
            print(f"[ NOTE ] 오차 범위가 {config.pos_val} 이하이므로 학습을 종료합니다.")
            break

        if ep > config.epoch:
            print(f"[ NOTE ] 최대 epoch {ep - 1}에 도달하여 학습을 종료합니다.")
            break

random.seed(40)
test_func(random.random())
# Out:
# epoch : 2 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : 38979.204087395185
# 오차범위 : 38979.20408739618
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.00099로 조정합니다.
# epoch : 3 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -392.6292376715097
# 오차범위 : 392.6292376705097
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.00199로 조정합니다.
# epoch : 4 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -194.78201850197428
# 오차범위 : 194.7820185009743
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.00299로 조정합니다.
# epoch : 5 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -129.27486460838387
# 오차범위 : 129.27486460738388
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.0039900000000000005로 조정합니다.
# epoch : 6 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -96.60396495603544
# 오차범위 : 96.60396495503544
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.0049900000000000005로 조정합니다.
# epoch : 7 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -77.02808249918256
# 오차범위 : 77.02808249818256
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.0059900000000000005로 조정합니다.
# epoch : 8 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -63.988776226886344
# 오차범위 : 63.98877622588635
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.0069900000000000006로 조정합니다.
# epoch : 9 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -54.68064720384505
# 오차범위 : 54.68064720284505
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.00799로 조정합니다.
# epoch : 10 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -47.702751539262266
# 오차범위 : 47.70275153826227
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.008990000000000001로 조정합니다.
# epoch : 11 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -42.27747967237775
# 오차범위 : 42.277479671377755
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.009990000000000002로 조정합니다.
# epoch : 12 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -37.93857722825056
# 오차범위 : 37.93857722725056
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.010990000000000003로 조정합니다.
# epoch : 13 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -34.38949115700961
# 오차범위 : 34.38949115600961
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.011990000000000004로 조정합니다.
# epoch : 14 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -31.432601875147824
# 오차범위 : 31.432601874147824
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.012990000000000005로 조정합니다.
# epoch : 15 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -28.931142639475315
# 오차범위 : 28.931142638475315
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.013990000000000006로 조정합니다.
# epoch : 16 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -26.787450855045833
# 오차범위 : 26.787450854045833
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.014990000000000007로 조정합니다.
# epoch : 17 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -24.92992466343328
# 오차범위 : 24.92992466243328
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.015990000000000008로 조정합니다.
# epoch : 18 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -23.304873869366315
# 오차범위 : 23.304873868366315
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.01699000000000001로 조정합니다.
# epoch : 19 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -21.871248703748943
# 오차범위 : 21.871248702748943
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.01799000000000001로 조정합니다.
# epoch : 20 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -20.597126642372164
# 오차범위 : 20.597126641372164
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.01899000000000001로 조정합니다.
# epoch : 21 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -19.457309234511598
# 오차범위 : 19.457309233511598
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.01999000000000001로 조정합니다.
# epoch : 22 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -18.43164024360214
# 오차범위 : 18.43164024260214
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.020990000000000012로 조정합니다.
# epoch : 23 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -17.5038045480821
# 오차범위 : 17.5038045470821
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.021990000000000013로 조정합니다.
# epoch : 24 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -16.66045476369889
# 오차범위 : 16.66045476269889
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.022990000000000014로 조정합니다.
# epoch : 25 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -15.89056580257729
# 오차범위 : 15.89056580157729
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.023990000000000015로 조정합니다.
# epoch : 26 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -15.184950859782283
# 오차범위 : 15.184950858782283
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.024990000000000016로 조정합니다.
# epoch : 27 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -14.535893609590904
# 오차범위 : 14.535893608590904
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.025990000000000017로 조정합니다.
# epoch : 28 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -13.936865312205548
# 오차범위 : 13.936865311205548
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.026990000000000017로 조정합니다.
# epoch : 29 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -13.382304808934302
# 오차범위 : 13.382304807934302
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.02799000000000002로 조정합니다.
# epoch : 30 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -12.867445678104497
# 오차범위 : 12.867445677104497
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.02899000000000002로 조정합니다.
# epoch : 31 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -12.388179164157451
# 오차범위 : 12.388179163157451
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.02999000000000002로 조정합니다.
# epoch : 32 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -11.940944530065556
# 오차범위 : 11.940944529065556
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.03099000000000002로 조정합니다.
# epoch : 33 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -11.522640638710357
# 오차범위 : 11.522640637710357
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.03199000000000002로 조정합니다.
# epoch : 34 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -11.13055411793479
# 오차범위 : 11.13055411693479
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.03299000000000002로 조정합니다.
# epoch : 35 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -10.762300590454197
# 오차범위 : 10.762300589454197
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.03399000000000002로 조정합니다.
# epoch : 36 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -10.415776278010886
# 오차범위 : 10.415776277010886
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.03499000000000002로 조정합니다.
# epoch : 37 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -10.089117904330552
# 오차범위 : 10.089117903330552
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.03599000000000002로 조정합니다.
# epoch : 38 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -9.780669282776259
# 오차범위 : 9.780669281776259
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.03699000000000002로 조정합니다.
# epoch : 39 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -9.488953323685616
# 오차범위 : 9.488953322685616
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.037990000000000024로 조정합니다.
# epoch : 40 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -9.212648462765602
# 오차범위 : 9.212648461765601
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.038990000000000025로 조정합니다.
# epoch : 41 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -8.95056871681838
# 오차범위 : 8.95056871581838
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.039990000000000026로 조정합니다.
# epoch : 42 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -8.701646731856458
# 오차범위 : 8.701646730856458
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.040990000000000026로 조정합니다.
# epoch : 43 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -8.464919312586774
# 오차범위 : 8.464919311586774
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.04199000000000003로 조정합니다.
# epoch : 44 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -8.239515019603752
# 오차범위 : 8.239515018603752
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.04299000000000003로 조정합니다.
# epoch : 45 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -8.024643497609231
# 오차범위 : 8.024643496609231
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.04399000000000003로 조정합니다.
# epoch : 46 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -7.819586259206063
# 오차범위 : 7.819586258206063
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.04499000000000003로 조정합니다.
# epoch : 47 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -7.623688697792389
# 오차범위 : 7.623688696792389
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.04599000000000003로 조정합니다.
# epoch : 48 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -7.436353142478997
# 오차범위 : 7.436353141478997
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.04699000000000003로 조정합니다.
# epoch : 49 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -7.2570327998016575
# 오차범위 : 7.257032798801657
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.04799000000000003로 조정합니다.
# epoch : 50 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -7.085226452877369
# 오차범위 : 7.085226451877369
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.048990000000000034로 조정합니다.
# epoch : 51 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -6.920473809776006
# 오차범위 : 6.920473808776006
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.049990000000000034로 조정합니다.
# epoch : 52 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -6.762351410199172
# 오차범위 : 6.762351409199172
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.050990000000000035로 조정합니다.
# epoch : 53 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -6.610469013820698
# 오차범위 : 6.6104690128206975
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.051990000000000036로 조정합니다.
# epoch : 54 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -6.464466405437361
# 오차범위 : 6.464466404437361
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.05299000000000004로 조정합니다.
# epoch : 55 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -6.324010561868918
# 오차범위 : 6.324010560868918
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.05399000000000004로 조정합니다.
# epoch : 56 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -6.1887931337054605
# 오차범위 : 6.18879313270546
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.05499000000000004로 조정합니다.
# epoch : 57 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -6.058528201823176
# 오차범위 : 6.058528200823176
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.05599000000000004로 조정합니다.
# epoch : 58 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -5.932950274316503
# 오차범위 : 5.932950273316503
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.05699000000000004로 조정합니다.
# epoch : 59 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -5.811812494316502
# 오차범위 : 5.811812493316502
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.05799000000000004로 조정합니다.
# epoch : 60 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -5.69488503323943
# 오차범위 : 5.69488503223943
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.05899000000000004로 조정합니다.
# epoch : 61 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -5.581953647461449
# 오차범위 : 5.581953646461449
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.05999000000000004로 조정합니다.
# epoch : 62 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -5.472818379350043
# 오차범위 : 5.472818378350043
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.060990000000000044로 조정합니다.
# epoch : 63 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -5.367292386083774
# 오차범위 : 5.367292385083774
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.061990000000000045로 조정합니다.
# epoch : 64 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -5.265200881830454
# 오차범위 : 5.265200880830454
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.06299000000000005로 조정합니다.
# epoch : 65 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -5.166380180686243
# 오차범위 : 5.166380179686243
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.06399000000000005로 조정합니다.
# epoch : 66 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -5.0706768293533235
# 오차범위 : 5.0706768283533235
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.06499000000000005로 조정합니다.
# epoch : 67 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -4.977946819890419
# 오차범위 : 4.977946818890419
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.06599000000000005로 조정합니다.
# epoch : 68 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -4.888054874042376
# 오차범위 : 4.888054873042376
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.06699000000000005로 조정합니다.
# epoch : 69 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -4.800873791669215
# 오차범위 : 4.800873790669215
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.06799000000000005로 조정합니다.
# epoch : 70 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -4.7162838566752585
# 오차범위 : 4.716283855675258
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.06899000000000005로 조정합니다.
# epoch : 71 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -4.6341722946041
# 오차범위 : 4.6341722936041
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.06999000000000005로 조정합니다.
# epoch : 72 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -4.554432776732148
# 오차범위 : 4.554432775732148
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.07099000000000005로 조정합니다.
# epoch : 73 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -4.4769649660756645
# 오차범위 : 4.476964965075664
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.07199000000000005로 조정합니다.
# epoch : 74 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -4.40167410123588
# 오차범위 : 4.40167410023588
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.07299000000000005로 조정합니다.
# epoch : 75 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -4.328470614453306
# 오차범위 : 4.328470613453306
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.07399000000000006로 조정합니다.
# epoch : 76 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -4.257269780634886
# 오차범위 : 4.2572697796348855
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.07499000000000006로 조정합니다.
# epoch : 77 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -4.187991394462694
# 오차범위 : 4.187991393462694
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.07599000000000006로 조정합니다.
# epoch : 78 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -4.120559472997511
# 오차범위 : 4.1205594719975105
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.07699000000000006로 조정합니다.
# epoch : 79 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -4.054901981459124
# 오차범위 : 4.054901980459124
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.07799000000000006로 조정합니다.
# epoch : 80 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -3.9909505801032457
# 오차범위 : 3.9909505791032456
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.07899000000000006로 조정합니다.
# epoch : 81 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -3.9286403903253873
# 오차범위 : 3.928640389325387
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.07999000000000006로 조정합니다.
# epoch : 82 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -3.8679097783092127
# 오차범위 : 3.8679097773092126
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.08099000000000006로 조정합니다.
# epoch : 83 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -3.808700154702905
# 오차범위 : 3.808700153702905
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.08199000000000006로 조정합니다.
# epoch : 84 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -3.7509557889552236
# 오차범위 : 3.7509557879552236
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.08299000000000006로 조정합니다.
# epoch : 85 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -3.6946236370746512
# 오차범위 : 3.694623636074651
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.08399000000000006로 조정합니다.
# epoch : 86 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -3.6396531816929967
# 오차범위 : 3.6396531806929966
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.08499000000000007로 조정합니다.
# epoch : 87 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -3.585996283419944
# 오차범위 : 3.585996282419944
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.08599000000000007로 조정합니다.
# epoch : 88 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -3.533607042569486
# 오차범위 : 3.533607041569486
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.08699000000000007로 조정합니다.
# epoch : 89 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -3.482441670423545
# 오차범위 : 3.4824416694235447
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.08799000000000007로 조정합니다.
# epoch : 90 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -3.432458369274146
# 오차범위 : 3.432458368274146
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.08899000000000007로 조정합니다.
# epoch : 91 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -3.3836172205535253
# 오차범위 : 3.3836172195535252
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.08999000000000007로 조정합니다.
# epoch : 92 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -3.3358800804231215
# 오차범위 : 3.3358800794231214
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.09099000000000007로 조정합니다.
# epoch : 93 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -3.28921048224756
# 오차범위 : 3.2892104812475598
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.09199000000000007로 조정합니다.
# epoch : 94 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -3.2435735454297734
# 오차범위 : 3.2435735444297733
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.09299000000000007로 조정합니다.
# epoch : 95 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -3.198935890128355
# 오차범위 : 3.198935889128355
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.09399000000000007로 조정합니다.
# epoch : 96 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -3.1552655574191184
# 오차범위 : 3.1552655564191183
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.09499000000000007로 조정합니다.
# epoch : 97 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -3.1125319344996063
# 오차범위 : 3.112531933499606
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.09599000000000008로 조정합니다.
# epoch : 98 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -3.070705684568858
# 오차범위 : 3.0707056835688578
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.09699000000000008로 조정합니다.
# epoch : 99 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -3.029758681044948
# 오차범위 : 3.029758680044948
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.09799000000000008로 조정합니다.
# epoch : 100 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -2.9896639458104897
# 오차범위 : 2.9896639448104896
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.09899000000000008로 조정합니다.
# epoch : 101 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -2.950395591201197
# 오차범위 : 2.950395590201197
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.09999000000000008로 조정합니다.
# epoch : 102 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -2.911928765475538
# 오차범위 : 2.911928764475538
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.10099000000000008로 조정합니다.
# epoch : 103 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -2.8742396015241205
# 오차범위 : 2.8742396005241204
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.10199000000000008로 조정합니다.
# epoch : 104 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -2.8373051685965214
# 오차범위 : 2.8373051675965213
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.10299000000000008로 조정합니다.
# epoch : 105 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -2.801103426840407
# 오차범위 : 2.801103425840407
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.10399000000000008로 조정합니다.
# epoch : 106 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -2.765613184463695
# 오차범위 : 2.765613183463695
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.10499000000000008로 조정합니다.
# epoch : 107 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -2.7308140573448165
# 오차범위 : 2.7308140563448164
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.10599000000000008로 조정합니다.
# epoch : 108 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -2.696686430929456
# 오차범위 : 2.6966864299294557
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.10699000000000009로 조정합니다.
# epoch : 109 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -2.6632114242641025
# 오차범위 : 2.6632114232641024
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.10799000000000009로 조정합니다.
# epoch : 110 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -2.6303708560279797
# 오차범위 : 2.6303708550279796
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.10899000000000009로 조정합니다.
# epoch : 111 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -2.5981472124349247
# 오차범위 : 2.5981472114349247
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.10999000000000009로 조정합니다.
# epoch : 112 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -2.5665236168862893
# 오차범위 : 2.566523615886289
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.11099000000000009로 조정합니다.
# epoch : 113 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -2.535483801264356
# 오차범위 : 2.535483800264356
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.11199000000000009로 조정합니다.
# epoch : 114 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -2.505012078763784
# 오차범위 : 2.505012077763784
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.11299000000000009로 조정합니다.
# epoch : 115 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -2.47509331816576
# 오차범위 : 2.47509331716576
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.11399000000000009로 조정합니다.
# epoch : 116 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -2.4457129194662883
# 오차범위 : 2.4457129184662882
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.11499000000000009로 조정합니다.
# epoch : 117 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -2.416856790776161
# 오차범위 : 2.416856789776161
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.11599000000000009로 조정합니다.
# epoch : 118 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -2.3885113264158906
# 오차범위 : 2.3885113254158905
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.1169900000000001로 조정합니다.
# epoch : 119 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -2.360663386134071
# 오차범위 : 2.360663385134071
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.1179900000000001로 조정합니다.
# epoch : 120 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -2.3333002753825602
# 오차범위 : 2.33330027438256
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.1189900000000001로 조정합니다.
# epoch : 121 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -2.3064097265862578
# 오차범위 : 2.3064097255862577
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.1199900000000001로 조정합니다.
# epoch : 122 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -2.2799798813495222
# 오차범위 : 2.279979880349522
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.1209900000000001로 조정합니다.
# epoch : 123 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -2.253999273544964
# 오차범위 : 2.253999272544964
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.1219900000000001로 조정합니다.
# epoch : 124 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -2.2284568132340503
# 오차범위 : 2.2284568122340502
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.1229900000000001로 조정합니다.
# epoch : 125 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -2.203341771372123
# 오차범위 : 2.203341770372123
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.1239900000000001로 조정합니다.
# epoch : 126 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -2.1786437652535886
# 오차범위 : 2.1786437642535885
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.1249900000000001로 조정합니다.
# epoch : 127 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -2.154352744655789
# 오차범위 : 2.1543527436557888
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.1259900000000001로 조정합니다.
# epoch : 128 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -2.1304589786427717
# 오차범위 : 2.1304589776427716
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.1269900000000001로 조정합니다.
# epoch : 129 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -2.106953042992544
# 오차범위 : 2.106953041992544
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.1279900000000001로 조정합니다.
# epoch : 130 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -2.0838258082137555
# 오차범위 : 2.0838258072137554
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.1289900000000001로 조정합니다.
# epoch : 131 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -2.0610684281197775
# 오차범위 : 2.0610684271197774
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.1299900000000001로 조정합니다.
# epoch : 132 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -2.0386723289302022
# 오차범위 : 2.038672327930202
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.1309900000000001로 조정합니다.
# epoch : 133 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -2.0166291988715446
# 오차범위 : 2.0166291978715445
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.1319900000000001로 조정합니다.
# epoch : 134 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.9949309782507008
# 오차범위 : 1.9949309772507007
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.1329900000000001로 조정합니다.
# epoch : 135 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.9735698499762493
# 오차범위 : 1.9735698489762492
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.1339900000000001로 조정합니다.
# epoch : 136 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.9525382305042314
# 오차범위 : 1.9525382295042313
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.1349900000000001로 조정합니다.
# epoch : 137 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.9318287611863625
# 오차범위 : 1.9318287601863624
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.1359900000000001로 조정합니다.
# epoch : 138 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.9114342999999983
# 오차범위 : 1.9114342989999982
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.1369900000000001로 조정합니다.
# epoch : 139 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.8913479136403084
# 오차범위 : 1.8913479126403083
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.1379900000000001로 조정합니다.
# epoch : 140 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.8715628699563243
# 오차범위 : 1.8715628689563242
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.1389900000000001로 조정합니다.
# epoch : 141 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.8520726307135014
# 오차범위 : 1.8520726297135013
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.13999000000000011로 조정합니다.
# epoch : 142 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.8328708446665072
# 오차범위 : 1.832870843666507
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.14099000000000012로 조정합니다.
# epoch : 143 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.8139513409267987
# 오차범위 : 1.8139513399267986
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.14199000000000012로 조정합니다.
# epoch : 144 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.795308122610489
# 오차범위 : 1.795308121610489
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.14299000000000012로 조정합니다.
# epoch : 145 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.7769353607527445
# 오차범위 : 1.7769353597527444
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.14399000000000012로 조정합니다.
# epoch : 146 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.7588273884757974
# 오차범위 : 1.7588273874757974
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.14499000000000012로 조정합니다.
# epoch : 147 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.7409786953982862
# 오차범위 : 1.7409786943982861
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.14599000000000012로 조정합니다.
# epoch : 148 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.7233839222743932
# 오차범위 : 1.723383921274393
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.14699000000000012로 조정합니다.
# epoch : 149 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.706037855851798
# 오차범위 : 1.7060378548517978
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.14799000000000012로 조정합니다.
# epoch : 150 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.6889354239381318
# 오차범위 : 1.6889354229381317
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.14899000000000012로 조정합니다.
# epoch : 151 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.6720716906661035
# 오차범위 : 1.6720716896661034
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.14999000000000012로 조정합니다.
# epoch : 152 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.6554418519480574
# 오차범위 : 1.6554418509480573
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.15099000000000012로 조정합니다.
# epoch : 153 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.6390412311111473
# 오차범위 : 1.6390412301111472
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.15199000000000013로 조정합니다.
# epoch : 154 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.622865274704845
# 오차범위 : 1.622865273704845
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.15299000000000013로 조정합니다.
# epoch : 155 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.6069095484728573
# 오차범위 : 1.6069095474728572
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.15399000000000013로 조정합니다.
# epoch : 156 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.5911697334820205
# 오차범위 : 1.5911697324820204
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.15499000000000013로 조정합니다.
# epoch : 157 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.5756416224010412
# 오차범위 : 1.5756416214010411
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.15599000000000013로 조정합니다.
# epoch : 158 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.5603211159223982
# 오차범위 : 1.5603211149223981
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.15699000000000013로 조정합니다.
# epoch : 159 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.5452042193209843
# 오차범위 : 1.5452042183209842
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.15799000000000013로 조정합니다.
# epoch : 160 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.530287039143465
# 오차범위 : 1.530287038143465
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.15899000000000013로 조정합니다.
# epoch : 161 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.515565780022567
# 오차범위 : 1.515565779022567
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.15999000000000013로 조정합니다.
# epoch : 162 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.501036741610859
# 오차범위 : 1.501036740610859
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.16099000000000013로 조정합니다.
# epoch : 163 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.4866963156288018
# 오차범위 : 1.4866963146288017
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.16199000000000013로 조정합니다.
# epoch : 164 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.4725409830221572
# 오차범위 : 1.472540982022157
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.16299000000000013로 조정합니다.
# epoch : 165 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.4585673112240305
# 오차범위 : 1.4585673102240304
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.16399000000000014로 조정합니다.
# epoch : 166 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.4447719515171107
# 오차범위 : 1.4447719505171106
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.16499000000000014로 조정합니다.
# epoch : 167 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.4311516364918244
# 오차범위 : 1.4311516354918243
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.16599000000000014로 조정합니다.
# epoch : 168 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.4177031775963929
# 오차범위 : 1.4177031765963928
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.16699000000000014로 조정합니다.
# epoch : 169 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.4044234627749044
# 오차범위 : 1.4044234617749043
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.16799000000000014로 조정합니다.
# epoch : 170 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.3913094541897713
# 오차범위 : 1.3913094531897712
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.16899000000000014로 조정합니다.
# epoch : 171 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.378358186025039
# 오차범위 : 1.3783581850250388
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.16999000000000014로 조정합니다.
# epoch : 172 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.365566762367251
# 오차범위 : 1.3655667613672509
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.17099000000000014로 조정합니다.
# epoch : 173 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.3529323551606667
# 오차범위 : 1.3529323541606666
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.17199000000000014로 조정합니다.
# epoch : 174 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.3404522022338325
# 오차범위 : 1.3404522012338325
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.17299000000000014로 조정합니다.
# epoch : 175 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.3281236053945888
# 오차범위 : 1.3281236043945888
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.17399000000000014로 조정합니다.
# epoch : 176 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.3159439285907932
# 오차범위 : 1.3159439275907931
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.17499000000000015로 조정합니다.
# epoch : 177 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.3039105961340967
# 오차범위 : 1.3039105951340966
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.17599000000000015로 조정합니다.
# epoch : 178 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.2920210909842982
# 오차범위 : 1.292021089984298
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.17699000000000015로 조정합니다.
# epoch : 179 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.2802729530918489
# 오차범위 : 1.2802729520918488
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.17799000000000015로 조정합니다.
# epoch : 180 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.2686637777962508
# 오차범위 : 1.2686637767962508
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.17899000000000015로 조정합니다.
# epoch : 181 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.257191214278135
# 오차범위 : 1.2571912132781349
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.17999000000000015로 조정합니다.
# epoch : 182 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.2458529640629574
# 오차범위 : 1.2458529630629573
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.18099000000000015로 조정합니다.
# epoch : 183 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.2346467795742915
# 오차범위 : 1.2346467785742914
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.18199000000000015로 조정합니다.
# epoch : 184 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.2235704627348345
# 오차범위 : 1.2235704617348344
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.18299000000000015로 조정합니다.
# epoch : 185 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.2126218636132764
# 오차범위 : 1.2126218626132763
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.18399000000000015로 조정합니다.
# epoch : 186 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.2017988791153145
# 오차범위 : 1.2017988781153144
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.18499000000000015로 조정합니다.
# epoch : 187 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.191099451717113
# 오차범위 : 1.1910994507171129
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.18599000000000016로 조정합니다.
# epoch : 188 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.1805215682396415
# 오차범위 : 1.1805215672396414
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.18699000000000016로 조정합니다.
# epoch : 189 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.1700632586623296
# 오차범위 : 1.1700632576623295
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.18799000000000016로 조정합니다.
# epoch : 190 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.1597225949746082
# 오차범위 : 1.159722593974608
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.18899000000000016로 조정합니다.
# epoch : 191 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.1494976900638962
# 오차범위 : 1.1494976890638962
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.18999000000000016로 조정합니다.
# epoch : 192 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.13938669663873
# 오차범위 : 1.13938669563873
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.19099000000000016로 조정합니다.
# epoch : 193 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.1293878061857094
# 오차범위 : 1.1293878051857094
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.19199000000000016로 조정합니다.
# epoch : 194 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.1194992479590593
# 오차범위 : 1.1194992469590592
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.19299000000000016로 조정합니다.
# epoch : 195 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.1097192880015976
# 오차범위 : 1.1097192870015975
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.19399000000000016로 조정합니다.
# epoch : 196 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.1000462281960002
# 오차범위 : 1.100046227196
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.19499000000000016로 조정합니다.
# epoch : 197 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.0904784053452503
# 오차범위 : 1.0904784043452502
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.19599000000000016로 조정합니다.
# epoch : 198 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.0810141902812573
# 오차범위 : 1.0810141892812573
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.19699000000000016로 조정합니다.
# epoch : 199 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.0716519870006136
# 오차범위 : 1.0716519860006135
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.19799000000000017로 조정합니다.
# epoch : 200 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.0623902318265623
# 오차범위 : 1.0623902308265623
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.19899000000000017로 조정합니다.
# epoch : 201 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.0532273925962212
# 오차범위 : 1.0532273915962211
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.19999000000000017로 조정합니다.
# epoch : 202 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.0441619678722107
# 오차범위 : 1.0441619668722106
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.20099000000000017로 조정합니다.
# epoch : 203 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.035192486177805
# 오차범위 : 1.035192485177805
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.20199000000000017로 조정합니다.
# epoch : 204 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.026317505254821
# 오차범위 : 1.026317504254821
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.20299000000000017로 조정합니다.
# epoch : 205 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.017535611343432
# 오차범위 : 1.0175356103434319
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.20399000000000017로 조정합니다.
# epoch : 206 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.008845418483181
# 오차범위 : 1.008845417483181
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.20499000000000017로 조정합니다.
# epoch : 207 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -1.0002455678344457
# 오차범위 : 1.0002455668344457
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.20599000000000017로 조정합니다.
# epoch : 208 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.9917347270196808
# 오차범위 : 0.9917347260196807
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.20699000000000017로 조정합니다.
# epoch : 209 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.9833115894837485
# 오차범위 : 0.9833115884837484
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.20799000000000017로 조정합니다.
# epoch : 210 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.974974873872718
# 오차범위 : 0.9749748728727179
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.20899000000000018로 조정합니다.
# epoch : 211 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.966723323430488
# 오차범위 : 0.9667233224304879
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.20999000000000018로 조정합니다.
# epoch : 212 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.9585557054126683
# 오차범위 : 0.9585557044126682
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.21099000000000018로 조정합니다.
# epoch : 213 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.9504708105171171
# 오차범위 : 0.950470809517117
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.21199000000000018로 조정합니다.
# epoch : 214 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.9424674523306132
# 오차범위 : 0.9424674513306132
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.21299000000000018로 조정합니다.
# epoch : 215 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.9345444667911053
# 오차범위 : 0.9345444657911052
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.21399000000000018로 조정합니다.
# epoch : 216 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.9267007116650555
# 오차범위 : 0.9267007106650554
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.21499000000000018로 조정합니다.
# epoch : 217 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.9189350660393596
# 오차범위 : 0.9189350650393595
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.21599000000000018로 조정합니다.
# epoch : 218 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.911246429827397
# 오차범위 : 0.9112464288273969
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.21699000000000018로 조정합니다.
# epoch : 219 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.9036337232887284
# 오차범위 : 0.9036337222887283
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.21799000000000018로 조정합니다.
# epoch : 220 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.8960958865620302
# 오차범위 : 0.8960958855620301
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.21899000000000018로 조정합니다.
# epoch : 221 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.888631879210816
# 오차범위 : 0.8886318782108159
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.21999000000000019로 조정합니다.
# epoch : 222 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.881240679781562
# 오차범위 : 0.8812406787815619
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.2209900000000002로 조정합니다.
# epoch : 223 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.873921285373822
# 오차범위 : 0.8739212843738219
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.2219900000000002로 조정합니다.
# epoch : 224 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.866672711221975
# 오차범위 : 0.8666727102219749
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.2229900000000002로 조정합니다.
# epoch : 225 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.8594939902882184
# 오차범위 : 0.8594939892882183
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.2239900000000002로 조정합니다.
# epoch : 226 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.852384172866477
# 오차범위 : 0.852384171866477
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.2249900000000002로 조정합니다.
# epoch : 227 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.8453423261968677
# 오차범위 : 0.8453423251968676
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.2259900000000002로 조정합니다.
# epoch : 228 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.8383675340904123
# 오차범위 : 0.8383675330904122
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.2269900000000002로 조정합니다.
# epoch : 229 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.8314588965636629
# 오차범위 : 0.8314588955636628
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.2279900000000002로 조정합니다.
# epoch : 230 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.8246155294829562
# 오차범위 : 0.8246155284829562
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.2289900000000002로 조정합니다.
# epoch : 231 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.8178365642179802
# 오차범위 : 0.8178365632179802
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.2299900000000002로 조정합니다.
# epoch : 232 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.8111211473043928
# 오차범위 : 0.8111211463043927
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.2309900000000002로 조정합니다.
# epoch : 233 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.8044684401151949
# 오차범위 : 0.8044684391151948
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.2319900000000002로 조정합니다.
# epoch : 234 ==============================
# ...
# 오차범위 : 0.08411942786241564
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.4669900000000004로 조정합니다.
# epoch : 469 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.082781919465062
# 오차범위 : 0.08278191846506192
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.4679900000000004로 조정합니다.
# epoch : 470 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.08145137310981065
# 오차범위 : 0.08145137210981057
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.4689900000000004로 조정합니다.
# epoch : 471 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.08012774257146722
# 오차범위 : 0.08012774157146714
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.4699900000000004로 조정합니다.
# epoch : 472 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.07881098103542238
# 오차범위 : 0.07881098003542229
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.4709900000000004로 조정합니다.
# epoch : 473 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.07750104209325408
# 오차범위 : 0.077501041093254
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.4719900000000004로 조정합니다.
# epoch : 474 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.07619787973838966
# 오차범위 : 0.07619787873838958
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.4729900000000004로 조정합니다.
# epoch : 475 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.07490144836181917
# 오차범위 : 0.07490144736181908
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.4739900000000004로 조정합니다.
# epoch : 476 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.07361170274786734
# 오차범위 : 0.07361170174786726
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.4749900000000004로 조정합니다.
# epoch : 477 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.0723285980700149
# 오차범위 : 0.07232859707001482
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.4759900000000004로 조정합니다.
# epoch : 478 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.07105208988677694
# 오차범위 : 0.07105208888677686
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.4769900000000004로 조정합니다.
# epoch : 479 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.0697821341376293
# 오차범위 : 0.06978213313762922
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.4779900000000004로 조정합니다.
# epoch : 480 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.06851868713899016
# 오차범위 : 0.06851868613899008
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.4789900000000004로 조정합니다.
# epoch : 481 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.06726170558024828
# 오차범위 : 0.0672617045802482
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.4799900000000004로 조정합니다.
# epoch : 482 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.06601114651984503
# 오차범위 : 0.06601114551984495
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.4809900000000004로 조정합니다.
# epoch : 483 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.06476696738140149
# 오차범위 : 0.0647669663814014
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.4819900000000004로 조정합니다.
# epoch : 484 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.06352912594989787
# 오차범위 : 0.06352912494989779
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.4829900000000004로 조정합니다.
# epoch : 485 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.06229758036789675
# 오차범위 : 0.06229757936789667
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.4839900000000004로 조정합니다.
# epoch : 486 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.061072289131817045
# 오차범위 : 0.06107228813181696
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.4849900000000004로 조정합니다.
# epoch : 487 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.05985321108825059
# 오차범위 : 0.05985321008825051
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.4859900000000004로 조정합니다.
# epoch : 488 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.05864030543032803
# 오차범위 : 0.058640304430327944
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.4869900000000004로 조정합니다.
# epoch : 489 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.05743353169412595
# 오차범위 : 0.057433530694125864
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.4879900000000004로 조정합니다.
# epoch : 490 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.05623284975512212
# 오차범위 : 0.056232848755122036
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.4889900000000004로 조정합니다.
# epoch : 491 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.055038219824690614
# 오차범위 : 0.05503821882469053
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.4899900000000004로 조정합니다.
# epoch : 492 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.05384960244664386
# 오차범위 : 0.053849601446643774
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.4909900000000004로 조정합니다.
# epoch : 493 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.0526669584938132
# 오차범위 : 0.052666957493813116
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.4919900000000004로 조정합니다.
# epoch : 494 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.051490249164675254
# 오차범위 : 0.05149024816467517
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.49299000000000043로 조정합니다.
# epoch : 495 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.050319435980015655
# 오차범위 : 0.05031943498001557
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.49399000000000043로 조정합니다.
# epoch : 496 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.04915448077963722
# 오차범위 : 0.04915447977963714
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.49499000000000043로 조정합니다.
# epoch : 497 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.04799534571910451
# 오차범위 : 0.047995344719104424
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.49599000000000043로 조정합니다.
# epoch : 498 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.04684199326653157
# 오차범위 : 0.04684199226653149
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.49699000000000043로 조정합니다.
# epoch : 499 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.045694386199404996
# 오차범위 : 0.04569438519940491
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.49799000000000043로 조정합니다.
# epoch : 500 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.04455248760144908
# 오차범위 : 0.044552486601449
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.49899000000000043로 조정합니다.
# epoch : 501 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.04341626085952511
# 오차범위 : 0.043416259859525026
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.49999000000000043로 조정합니다.
# epoch : 502 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.042285669660571755
# 오차범위 : 0.04228566866057167
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5009900000000004로 조정합니다.
# epoch : 503 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.041160677988578684
# 오차범위 : 0.0411606769885786
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5019900000000004로 조정합니다.
# epoch : 504 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.040041250121599446
# 오차범위 : 0.040041249121599364
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5029900000000004로 조정합니다.
# epoch : 505 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.03892735062879841
# 오차범위 : 0.038927349628798326
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5039900000000004로 조정합니다.
# epoch : 506 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.03781894436753354
# 오차범위 : 0.037818943367533456
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5049900000000004로 조정합니다.
# epoch : 507 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.036715996480474036
# 오차범위 : 0.036715995480473954
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5059900000000004로 조정합니다.
# epoch : 508 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.03561847239275218
# 오차범위 : 0.0356184713927521
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5069900000000004로 조정합니다.
# epoch : 509 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.03452633780914914
# 오차범위 : 0.03452633680914906
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5079900000000004로 조정합니다.
# epoch : 510 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.033439558711314016
# 오차범위 : 0.03343955771131393
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5089900000000004로 조정합니다.
# epoch : 511 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.03235810135501598
# 오차범위 : 0.0323581003550159
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5099900000000004로 조정합니다.
# epoch : 512 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.03128193226742878
# 오차범위 : 0.031281931267428696
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5109900000000004로 조정합니다.
# epoch : 513 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.03021101824444731
# 오차범위 : 0.030211017244447226
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5119900000000004로 조정합니다.
# epoch : 514 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.02914532634803577
# 오차범위 : 0.029145325348035687
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5129900000000004로 조정합니다.
# epoch : 515 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.02808482390360698
# 오차범위 : 0.028084822903606897
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5139900000000004로 조정합니다.
# epoch : 516 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.027029478497432417
# 오차범위 : 0.027029477497432335
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5149900000000004로 조정합니다.
# epoch : 517 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.025979257974082584
# 오차범위 : 0.0259792569740825
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5159900000000004로 조정합니다.
# epoch : 518 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.024934130433897275
# 오차범위 : 0.024934129433897192
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5169900000000004로 조정합니다.
# epoch : 519 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.023894064230485325
# 오차범위 : 0.023894063230485242
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5179900000000004로 조정합니다.
# epoch : 520 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.022859027968253467
# 오차범위 : 0.022859026968253385
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5189900000000004로 조정합니다.
# epoch : 521 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.021828990499963903
# 오차범위 : 0.02182898949996382
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5199900000000004로 조정합니다.
# epoch : 522 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.020803920924320162
# 오차범위 : 0.02080391992432008
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5209900000000004로 조정합니다.
# epoch : 523 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.019783788583580934
# 오차범위 : 0.01978378758358085
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5219900000000004로 조정합니다.
# epoch : 524 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.018768563061201404
# 오차범위 : 0.01876856206120132
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5229900000000004로 조정합니다.
# epoch : 525 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.017758214179501856
# 오차범위 : 0.017758213179501773
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5239900000000004로 조정합니다.
# epoch : 526 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.01675271199736303
# 오차범위 : 0.016752710997362946
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5249900000000004로 조정합니다.
# epoch : 527 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.01575202680794799
# 오차범위 : 0.015752025807947906
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5259900000000004로 조정합니다.
# epoch : 528 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.014756129136450072
# 오차범위 : 0.014756128136449989
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5269900000000004로 조정합니다.
# epoch : 529 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.013764989737866657
# 오차범위 : 0.013764988737866574
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5279900000000004로 조정합니다.
# epoch : 530 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.01277857959479829
# 오차범위 : 0.012778578594798208
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5289900000000004로 조정합니다.
# epoch : 531 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.011796869915272958
# 오차범위 : 0.011796868915272875
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5299900000000004로 조정합니다.
# epoch : 532 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.010819832130595067
# 오차범위 : 0.010819831130594985
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5309900000000004로 조정합니다.
# epoch : 533 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.009847437893218893
# 오차범위 : 0.00984743689321881
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5319900000000004로 조정합니다.
# epoch : 534 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.008879659074646109
# 오차범위 : 0.008879658074646026
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5329900000000004로 조정합니다.
# epoch : 535 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.007916467763347104
# 오차범위 : 0.007916466763347021
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5339900000000004로 조정합니다.
# epoch : 536 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.006957836262705793
# 오차범위 : 0.006957835262705711
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5349900000000004로 조정합니다.
# epoch : 537 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.006003737088987586
# 오차범위 : 0.006003736088987504
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5359900000000004로 조정합니다.
# epoch : 538 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.005054142969330212
# 오차범위 : 0.00505414196933013
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5369900000000004로 조정합니다.
# epoch : 539 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.004109026839757125
# 오차범위 : 0.004109025839757043
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5379900000000004로 조정합니다.
# epoch : 540 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.003168361843213176
# 오차범위 : 0.003168360843213094
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5389900000000004로 조정합니다.
# epoch : 541 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.002232121327622263
# 오차범위 : 0.002232120327622181
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5399900000000004로 조정합니다.
# epoch : 542 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.0013002788439666821
# 오차범위 : 0.0013002778439665998
# [ NOTE ] 오차 범위가 0.001 이상이므로 h 값을 -0.5409900000000004로 조정합니다.
# epoch : 543 ==============================
# AutoGrad loss : -1.000000082240371e-09, Numerical loss : -0.0003728081443878887
# 오차범위 : 0.00037280714438780646
# [ NOTE ] 오차 범위가 0.001 이하이므로 학습을 종료합니다.
# /var/folders/kv/v9_z1s811lg_n6c7m1gjb7w40000gn/T/ipykernel_52196/1104287699.py:11: RuntimeWarning: invalid value encountered in log
#   y_pred = np.log(y_pred + eps)

# %%
# func = lambda x: loss_func(y_true, x)
# y_pred = loss_func(x, y_true)
# print(y_pred)

# print(numerical_func(func, y_pred))

# d = node * weight + bias
# d.backward()
# print(f"node 기울기 : {node.grad}")
# print(f"weight 기울기 : {weight.grad}")
# print(f"bias 기울기 : {bias.grad}")
# Out:
# 8.289306334078564
# -105748.25421859614
# node 기울기 : 0.0
# weight 기울기 : 0.0
# bias 기울기 : 2.0
